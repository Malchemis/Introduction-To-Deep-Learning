# %% [markdown]
# # CNN from scratch - Build a Custom Conv2d Module

# %%
# show version and all available gpu devices
import torch
print(torch.__version__)
if torch.cuda.is_available():
    for idx in range(torch.cuda.device_count()):
        print(torch.cuda.get_device_name(idx))
else:
    print('No GPU available')
# Out:
# 2.5.1
# NVIDIA GeForce GTX 1070 Ti

# %% [markdown]
# ## Implementing

# %% [markdown]
# MyConv2d is a custom re-implementation of the CNN.
#
# 2 versions were implemented. You can test these by commenting/un-commenting the code in the forward function :
# - `self.my_forward(x)` : A very slow but readable pythonic way of computing the convolutions
# - `self.fold_forward(x)` : Take advantages of methods from the Torch package like folding/unfolding to compute a forward pass in a better optimized way. (still slower than default as it runs in the interpreter as opposed to the C++ compiled modules)
#
# Which you can compare to the default method `self.default_forward`.

# %%
from torch import nn


class MyConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding='same', dilation=1, groups=1, bias=True):
        super(MyConv2d, self).__init__()        
        self.stride = (stride, stride) if isinstance(stride, int) else tuple(stride)
        self.dilation = (dilation, dilation) if isinstance(dilation, int) else tuple(dilation)
        self.kernel_size = (kernel_size, kernel_size) if isinstance(kernel_size, int) else tuple(kernel_size)
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.groups = self.check_params(groups)
        self.bias = bias

        if isinstance(padding, str):
            if padding.lower() == 'same':
                self.padding = tuple((s * (k - 1) // 2 for s, k in zip(self.stride, self.kernel_size)))
            elif padding.lower() == 'valid':
                self.padding = (0, 0)
            else:
                raise ValueError('Padding must be "same", "valid", or an integer.')
        else:
            self.padding = (padding, padding) if isinstance(padding, int) else tuple(padding)

        self.weight = nn.Parameter(
            torch.randn(out_channels, in_channels // groups, kernel_size, kernel_size)
        )
        self.bias = nn.Parameter(torch.randn(out_channels)) if bias else None
        
    def forward(self, x):
        # return self.my_forward(x) # a lot slower since it's not optimized, doesn't exploit parallelism
        return self.fold_forward(x)  # Optimized version using matrix multiplication and unfolding with parallelism
        # return self.default_forward(x) # Default PyTorch implementation
    
    def my_forward(self, x):
        """Reproduces F.conv2d with the specified parameters in a pythonic way without the explicit call to the function."""
        batch_size, in_channels, height, width = x.size()

        # Check dimensions
        assert in_channels == self.in_channels, \
            f'Expected input with {self.in_channels} channels, but got {in_channels} channels'

        # Calculate output dimensions
        out_height = (height + 2 * self.padding[0] - self.dilation[0] * (self.kernel_size[0] - 1) - 1) // self.stride[0] + 1
        out_width = (width + 2 * self.padding[1] - self.dilation[1] * (self.kernel_size[1] - 1) - 1) // self.stride[1] + 1

        # Apply padding if needed
        if self.padding != (0, 0):
            x = nn.functional.pad(x, (self.padding[1], self.padding[1], self.padding[0], self.padding[0]))

        # Initialize the output tensor
        out = torch.zeros((batch_size, self.out_channels, out_height, out_width), device=x.device)

        # Perform the convolution operation
        out_channels_per_group = self.out_channels // self.groups
        in_channels_per_group = self.in_channels // self.groups

        for g in range(self.groups):
            for i in range(out_height):
                for j in range(out_width):
                    h_start = i * self.stride[0]
                    h_end = h_start + self.kernel_size[0] * self.dilation[0]
                    w_start = j * self.stride[1]
                    w_end = w_start + self.kernel_size[1] * self.dilation[1]

                    x_slice = x[:, g * in_channels_per_group:(g + 1) * in_channels_per_group, h_start:h_end:self.dilation[0], w_start:w_end:self.dilation[1]]

                    out[:, g * out_channels_per_group:(g + 1) * out_channels_per_group, i, j] = \
                        torch.einsum('bijk,oijk->bo', x_slice, self.weight[g * out_channels_per_group:(g + 1) * out_channels_per_group]) + \
                        self.bias[g * out_channels_per_group:(g + 1) * out_channels_per_group]

        return out

    def fold_forward(self, x):
        """Reproduces F.conv2d with the specified parameters using torch methods"""
        n_batch, in_channels, in_height, in_width = x.size()
        out_height = (in_height + 2 * self.padding[0] - self.dilation[0] * (self.kernel_size[0] - 1) - 1) // self.stride[0] + 1
        out_width = (in_width + 2 * self.padding[1] - self.dilation[1] * (self.kernel_size[1] - 1) - 1) // self.stride[1] + 1
    
        # Pad the input tensor
        if self.padding != (0, 0):
            x = nn.functional.pad(x, (self.padding[1], self.padding[1], self.padding[0], self.padding[0]))
    
        # Unfold the input tensor to apply the convolution operation
        x = torch.nn.functional.unfold(x, self.kernel_size, dilation=self.dilation, stride=self.stride)
    
        # Reshape the weights
        weight = self.weight.view(self.weight.size(0), -1)
    
        # Perform matrix multiplication
        x = torch.matmul(x.permute(0, 2, 1), weight.t())
        
        # Reshape the output tensor
        x = x.view(n_batch, self.out_channels, out_height, out_width)
    
        return x + self.bias.view(1, -1, 1, 1) if self.bias is not None else x


    def default_forward(self, x):
        return F.conv2d(x, self.weight, self.bias, self.stride, self.padding, self.dilation, self.groups)

    def check_params(self, groups):
        """Checks the parameters of the Conv2d layer to ensure they are valid."""
        if groups <= 0:
            raise ValueError('groups must be a positive integer')
        if self.in_channels % groups != 0:
            raise ValueError('in_channels must be divisible by groups')
        if self.out_channels % groups != 0:
            raise ValueError('out_channels must be divisible by groups')
        return groups

# %% [markdown]
# ## Testing

# %% [markdown]
# Below is some code to test on MNIST. BEWARE, the groups and dilation parameters were not verified, only the kernel_size, stride, and padding.

# %%
import torch
from torch import nn
import torch.nn.functional as F

from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms

import pytorch_lightning as pl
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import EarlyStopping
import torchmetrics

class MNISTModel(pl.LightningModule):
    def __init__(self):
        super().__init__()
        self.mnist_val = None
        self.mnist_train = None
        self.mnist_test = None
        self.convBlock1 = nn.Sequential(
            MyConv2d(1, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.convBlock2 = nn.Sequential(
            MyConv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.fc_out = nn.Linear(64 * 7 * 7, 10)
        
        # Initialize metrics
        self.train_accuracy = torchmetrics.Accuracy(task='multiclass', num_classes=10)
        self.val_accuracy = torchmetrics.Accuracy(task='multiclass', num_classes=10)
        self.test_accuracy = torchmetrics.Accuracy(task='multiclass', num_classes=10)

    def forward(self, x):
        x = self.convBlock1(x)
        x = self.convBlock2(x)
        x = x.view(x.size(0), -1)  # Flatten the tensor
        return self.fc_out(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        logits = self.forward(x)
        loss = F.cross_entropy(logits, y)
        
        # Calculate and log accuracy
        preds = torch.argmax(logits, dim=1)
        acc = self.train_accuracy(preds, y)
        self.log('train_loss', loss)
        self.log('train_acc', acc, prog_bar=True)
        
        return loss
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        logits = self.forward(x)
        loss = F.cross_entropy(logits, y)
        
        # Calculate and log accuracy
        preds = torch.argmax(logits, dim=1)
        acc = self.val_accuracy(preds, y)
        self.log('val_loss', loss, prog_bar=True)
        self.log('val_acc', acc, prog_bar=True)
        
        return loss

    def test_step(self, batch, batch_idx):
        x, y = batch
        logits = self.forward(x)
        loss = F.cross_entropy(logits, y)
        
        # Calculate and log accuracy
        preds = torch.argmax(logits, dim=1)
        acc = self.test_accuracy(preds, y)
        self.log('test_loss', loss, prog_bar=True)
        self.log('test_acc', acc, prog_bar=True)
        
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=0.001)

    def prepare_data(self):
        # Download and prepare the MNIST dataset
        datasets.MNIST('../data/raw', train=True, download=True)
        datasets.MNIST('../data/raw', train=False, download=True)

    def setup(self, stage=None):
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.1307,), (0.3081,))
        ])
        if stage == 'fit' or stage is None:
            mnist_full = datasets.MNIST('../data/raw', train=True, transform=transform)
            self.mnist_train, self.mnist_val = random_split(mnist_full, [55000, 5000])
        if stage == 'test' or stage is None:
            self.mnist_test = datasets.MNIST('../data/raw', train=False, transform=transform)

    def train_dataloader(self):
        return DataLoader(self.mnist_train, batch_size=256, num_workers=8, shuffle=True, persistent_workers=True)

    def val_dataloader(self):
        return DataLoader(self.mnist_val, batch_size=128, num_workers=8, shuffle=False, persistent_workers=True)
    
    def test_dataloader(self):
        return DataLoader(self.mnist_test, batch_size=128, num_workers=8, shuffle=False, persistent_workers=True)

# %%
# EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_loss', # Metric to monitor
    patience=3,         # Number of epochs with no improvement after which training will be stopped
    verbose=True,       # Print messages when early stopping is triggered
    mode='min'          # Minimize the monitored metric
)

# Trainer with EarlyStopping callback
trainer = Trainer(max_epochs=50, callbacks=[early_stopping], accelerator='gpu', devices=1, default_root_dir='../models/cnn-scratch')
model = MNISTModel()
trainer.fit(model)

# Get best weights from checkpoint
best_model_path = trainer.checkpoint_callback.best_model_path
model = MNISTModel.load_from_checkpoint(best_model_path)

# Test the model
trainer.test(model)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ../data/raw/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 8.61MB/s]
# Extracting ../data/raw/MNIST/raw/train-images-idx3-ubyte.gz to ../data/raw/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ../data/raw/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 329kB/s]
# Extracting ../data/raw/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/raw/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ../data/raw/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.11MB/s]
# Extracting ../data/raw/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/raw/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ../data/raw/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 7.27MB/s]
# Extracting ../data/raw/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/raw/MNIST/raw
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name           | Type               | Params | Mode
# --------------------------------------------------------------
# 0 | convBlock1     | Sequential         | 320    | train
# 1 | convBlock2     | Sequential         | 18.5 K | train
# 2 | fc_out         | Linear             | 31.4 K | train
# 3 | train_accuracy | MulticlassAccuracy | 0      | train
# 4 | val_accuracy   | MulticlassAccuracy | 0      | train
# 5 | test_accuracy  | MulticlassAccuracy | 0      | train
# --------------------------------------------------------------
# 50.2 K    Trainable params
# 0         Non-trainable params
# 50.2 K    Total params
# 0.201     Total estimated model params size (MB)
# 12        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/malchemis/miniconda3/envs/iDL/lib/python3.12/site-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Epoch 0: 100%|██████████| 215/215 [00:03<00:00, 55.76it/s, v_num=0, train_acc=0.907]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 109.52it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 123.68it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 125.37it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 133.30it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 120.52it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 125.60it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 126.41it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 124.23it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 113.98it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 113.96it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 115.05it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 115.05it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 114.62it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 113.84it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 113.32it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 113.18it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 112.36it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 112.39it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 111.28it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 111.32it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 111.34it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 110.98it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 111.67it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 112.57it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 113.28it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 114.20it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 115.08it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 115.92it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 116.73it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 117.64it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 118.10it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 119.39it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 120.22it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 120.74it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 121.40it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 121.72it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 122.05it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 121.99it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 122.62it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 121.37it/s]
# Epoch 0: 100%|██████████| 215/215 [00:04<00:00, 50.42it/s, v_num=0, train_acc=0.907, val_loss=1.680, val_acc=0.913]
# Metric val_loss improved. New best score: 1.680
# Epoch 1: 100%|██████████| 215/215 [00:03<00:00, 56.30it/s, v_num=0, train_acc=0.944, val_loss=1.680, val_acc=0.913]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 77.99it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 101.79it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 63.96it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 73.07it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 82.45it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 89.76it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 95.56it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 100.14it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 103.66it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 106.59it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 103.10it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 102.42it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 104.47it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 105.13it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 107.15it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 108.89it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 106.57it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 108.11it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 108.09it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 107.51it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 108.66it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 107.87it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 108.31it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 109.58it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 110.80it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 111.03it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 111.39it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 112.21it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 113.31it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 114.25it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 114.88it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 115.75it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 116.21it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 117.36it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 117.60it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 118.16it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 118.63it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 119.25it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 119.68it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 121.39it/s]
# Epoch 1: 100%|██████████| 215/215 [00:04<00:00, 51.17it/s, v_num=0, train_acc=0.944, val_loss=1.000, val_acc=0.930]
# Metric val_loss improved by 0.675 >= min_delta = 0.0. New best score: 1.005
# Epoch 2: 100%|██████████| 215/215 [00:04<00:00, 52.71it/s, v_num=0, train_acc=0.931, val_loss=1.000, val_acc=0.930]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 40.50it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 46.56it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 52.77it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 59.60it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 59.44it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 64.96it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 69.04it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 68.47it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 61.32it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 62.24it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 62.99it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 61.42it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 62.09it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 63.06it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 64.07it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 63.78it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 64.15it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 63.86it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 63.66it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 64.53it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 65.70it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 64.87it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 65.73it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 66.38it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 67.34it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 67.73it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 68.97it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 69.79it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 70.58it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 71.59it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 72.73it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 73.74it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 74.34it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 75.03it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 75.93it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 76.58it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 76.99it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 77.40it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 77.78it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 78.77it/s]
# Epoch 2: 100%|██████████| 215/215 [00:04<00:00, 45.82it/s, v_num=0, train_acc=0.931, val_loss=0.771, val_acc=0.940]
# Metric val_loss improved by 0.233 >= min_delta = 0.0. New best score: 0.771
# Epoch 3: 100%|██████████| 215/215 [00:04<00:00, 50.68it/s, v_num=0, train_acc=0.894, val_loss=0.771, val_acc=0.940]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 119.30it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 135.26it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 140.67it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 126.34it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 118.70it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 118.60it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 122.91it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 121.42it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 112.84it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 109.61it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 109.96it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 108.14it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 108.75it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 110.30it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 110.65it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 112.99it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 106.26it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 105.56it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 106.83it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 104.86it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 105.32it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 106.56it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 106.69it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 105.54it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 106.29it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 106.21it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 105.86it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 106.60it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 106.21it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 106.21it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 106.28it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 106.24it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 106.56it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 106.77it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 106.40it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 106.62it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 106.99it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 107.40it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 107.33it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 108.38it/s]
# Epoch 3: 100%|██████████| 215/215 [00:04<00:00, 45.69it/s, v_num=0, train_acc=0.894, val_loss=0.640, val_acc=0.951]
# Metric val_loss improved by 0.131 >= min_delta = 0.0. New best score: 0.640
# Epoch 4: 100%|██████████| 215/215 [00:04<00:00, 53.02it/s, v_num=0, train_acc=0.991, val_loss=0.640, val_acc=0.951]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 65.08it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 68.30it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 62.98it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 72.86it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 77.51it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 82.84it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 86.13it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 88.83it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 92.90it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 96.20it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 91.40it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 92.31it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 94.97it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 96.76it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 99.22it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 100.16it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 102.38it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 101.68it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 101.80it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 102.47it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 101.20it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 100.26it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 100.37it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 101.50it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 102.06it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 103.42it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 104.31it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 105.10it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 105.71it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 106.57it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 106.79it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 107.25it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 107.96it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 108.39it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 108.29it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 109.05it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 109.36it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 110.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 110.18it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 111.74it/s]
# Epoch 4: 100%|██████████| 215/215 [00:04<00:00, 48.06it/s, v_num=0, train_acc=0.991, val_loss=0.441, val_acc=0.964]
# Metric val_loss improved by 0.199 >= min_delta = 0.0. New best score: 0.441
# Epoch 5: 100%|██████████| 215/215 [00:04<00:00, 49.53it/s, v_num=0, train_acc=0.981, val_loss=0.441, val_acc=0.964]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 139.54it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 121.77it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 115.32it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 108.04it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 111.25it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 107.70it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 111.76it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 112.36it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 106.25it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 102.85it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 100.82it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 102.47it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 103.34it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 101.88it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 101.02it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 101.19it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 102.42it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 102.48it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 103.59it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 103.29it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 103.73it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 103.64it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 102.96it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 102.26it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 101.88it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 102.73it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 103.16it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 103.62it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 104.11it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 104.84it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 105.24it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 105.71it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 106.50it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 106.75it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 107.42it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 107.27it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 107.96it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 108.12it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 108.41it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 109.67it/s]
# Epoch 6: 100%|██████████| 215/215 [00:05<00:00, 42.07it/s, v_num=0, train_acc=0.968, val_loss=0.601, val_acc=0.949]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 74.90it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 69.33it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 42.26it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 50.81it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 54.99it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 59.06it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 61.52it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 63.82it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 67.38it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 70.47it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 71.60it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 74.39it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 76.80it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 79.08it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 78.84it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 80.05it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 81.83it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 83.60it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 83.83it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 84.54it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 85.17it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 86.03it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 86.71it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 87.06it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 87.63it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 88.34it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 89.05it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 90.10it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 91.28it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 91.95it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 93.04it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 93.68it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 94.72it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 95.10it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 95.61it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 96.03it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 96.51it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 96.88it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 97.49it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 99.01it/s]
# Epoch 6: 100%|██████████| 215/215 [00:05<00:00, 38.69it/s, v_num=0, train_acc=0.968, val_loss=0.436, val_acc=0.961]
# Metric val_loss improved by 0.006 >= min_delta = 0.0. New best score: 0.436
# Epoch 7: 100%|██████████| 215/215 [00:04<00:00, 49.74it/s, v_num=0, train_acc=0.991, val_loss=0.436, val_acc=0.961]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 98.37it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 105.24it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 98.96it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 104.39it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 106.28it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 108.07it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 109.28it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 103.64it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 100.94it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 102.10it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 104.59it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 107.09it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 109.87it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 110.36it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 112.45it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 112.85it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 108.70it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 109.33it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 110.90it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 109.52it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 109.63it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 110.27it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 108.32it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 109.53it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 109.31it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 109.35it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 110.04it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 110.95it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 110.85it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 111.21it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 111.45it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 111.86it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 111.99it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 112.47it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 112.72it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 112.58it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 112.67it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 112.26it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 112.54it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 114.11it/s]
# Epoch 8: 100%|██████████| 215/215 [00:05<00:00, 42.30it/s, v_num=0, train_acc=0.986, val_loss=0.449, val_acc=0.964]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 75.06it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 54.48it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 68.44it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 55.00it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 61.33it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 67.63it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 69.29it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 72.46it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 75.63it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 77.71it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 80.52it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 80.10it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 83.28it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 84.34it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 85.30it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 87.10it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 89.54it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 91.43it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 92.51it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 91.66it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 92.78it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 92.86it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 91.92it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 92.88it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 93.40it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 94.25it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 94.97it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 96.13it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 97.01it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 98.34it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 98.88it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 99.37it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 100.40it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 101.09it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 101.90it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 102.70it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 103.21it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 103.51it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 104.08it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 105.34it/s]
# Epoch 9: 100%|██████████| 215/215 [00:05<00:00, 42.28it/s, v_num=0, train_acc=0.977, val_loss=0.580, val_acc=0.954]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 48.94it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 35.37it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 44.05it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 48.77it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 50.86it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 54.57it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 58.61it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 62.74it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 57.57it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 57.32it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 57.81it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 59.63it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 61.75it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 63.81it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 64.65it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 64.89it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 64.81it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 64.52it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 64.09it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 65.26it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 64.96it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 65.84it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 66.24it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 66.33it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 66.81it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 67.84it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 69.10it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 70.33it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 71.45it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 72.20it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 72.94it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 73.88it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 75.13it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 76.20it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 77.20it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 78.21it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 79.15it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 79.76it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 80.25it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 81.63it/s]
# Epoch 9: 100%|██████████| 215/215 [00:05<00:00, 38.02it/s, v_num=0, train_acc=0.977, val_loss=0.426, val_acc=0.968]
# Metric val_loss improved by 0.010 >= min_delta = 0.0. New best score: 0.426
# Epoch 10: 100%|██████████| 215/215 [00:04<00:00, 50.36it/s, v_num=0, train_acc=0.972, val_loss=0.426, val_acc=0.968]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 70.06it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 61.63it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 59.84it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 66.31it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 68.19it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 73.81it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 77.66it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 81.56it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 82.55it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 84.97it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 85.76it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 87.06it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 84.58it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 87.44it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 88.36it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 88.93it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 90.74it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 89.74it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 90.51it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 90.90it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 92.47it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 92.72it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 92.15it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 91.95it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 91.92it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 92.64it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 93.14it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 93.91it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 94.68it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 95.14it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 95.78it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 96.62it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 97.14it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 98.05it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 98.41it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 98.87it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 99.27it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 99.52it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 99.76it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 100.75it/s]
# Epoch 11: 100%|██████████| 215/215 [00:05<00:00, 42.24it/s, v_num=0, train_acc=0.981, val_loss=0.438, val_acc=0.963]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 90.49it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 99.29it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 113.29it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 109.11it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 102.14it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 99.41it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 94.77it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 97.57it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 86.08it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 88.20it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 86.97it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 87.59it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 90.16it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 89.28it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 90.97it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 90.21it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 88.27it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 88.74it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 86.92it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 88.65it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 90.23it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 91.40it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 89.61it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 90.05it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 90.68it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 90.87it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 92.06it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 93.15it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 94.16it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 94.68it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 95.38it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 96.07it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 96.66it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 97.25it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 97.97it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 98.49it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 99.18it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 99.73it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 99.83it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 100.89it/s]
# Epoch 11: 100%|██████████| 215/215 [00:05<00:00, 38.47it/s, v_num=0, train_acc=0.981, val_loss=0.393, val_acc=0.971]
# Metric val_loss improved by 0.033 >= min_delta = 0.0. New best score: 0.393
# Epoch 12: 100%|██████████| 215/215 [00:04<00:00, 52.87it/s, v_num=0, train_acc=0.977, val_loss=0.393, val_acc=0.971]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:01, 30.26it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 39.41it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 46.63it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 47.60it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 51.93it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 54.77it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 55.59it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 54.34it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 53.11it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 54.69it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 52.57it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 52.77it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 54.02it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 54.69it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 55.08it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 54.68it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 56.00it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 56.25it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 56.66it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 56.36it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 55.72it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 56.07it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 56.41it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 56.25it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 57.10it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 58.11it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 59.29it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 60.47it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 61.37it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 62.44it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 63.18it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 64.09it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 64.84it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 65.26it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 65.68it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 66.32it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 67.23it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 67.91it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 68.49it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 69.75it/s]
# Epoch 13: 100%|██████████| 215/215 [00:06<00:00, 35.34it/s, v_num=0, train_acc=0.986, val_loss=0.568, val_acc=0.960]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 93.37it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 75.71it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 80.88it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 75.40it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 70.25it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 68.01it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 64.31it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 68.43it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 61.28it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 59.48it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 56.97it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 56.75it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 57.43it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 57.96it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 59.78it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 61.12it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 61.45it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 61.06it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 61.09it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 60.46it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 60.56it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 60.74it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 59.93it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 60.85it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 61.94it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 62.34it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 62.54it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 63.15it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 62.77it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 63.18it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 64.10it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 64.28it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 64.54it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 65.23it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 65.36it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 65.73it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 66.26it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 66.88it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 66.79it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 67.51it/s]
# Epoch 13: 100%|██████████| 215/215 [00:06<00:00, 31.46it/s, v_num=0, train_acc=0.986, val_loss=0.369, val_acc=0.973]
# Metric val_loss improved by 0.024 >= min_delta = 0.0. New best score: 0.369
# Epoch 14: 100%|██████████| 215/215 [00:05<00:00, 42.78it/s, v_num=0, train_acc=0.981, val_loss=0.369, val_acc=0.973]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 150.25it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 158.18it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 160.57it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 155.84it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 156.14it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 147.01it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 149.47it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 152.02it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 134.33it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 136.16it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 138.40it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 140.24it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 141.66it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 139.05it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 139.29it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 140.49it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 139.46it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 139.73it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 139.31it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 138.06it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 135.53it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 136.20it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 136.70it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 135.35it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 135.94it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 136.10it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 135.44it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 135.80it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 136.34it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 136.45it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 136.56it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 135.31it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 135.04it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 135.21it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 135.50it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 135.91it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 134.54it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 132.29it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 132.40it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 133.91it/s]
# Epoch 14: 100%|██████████| 215/215 [00:05<00:00, 39.78it/s, v_num=0, train_acc=0.981, val_loss=0.348, val_acc=0.971]
# Metric val_loss improved by 0.021 >= min_delta = 0.0. New best score: 0.348
# Epoch 15: 100%|██████████| 215/215 [00:04<00:00, 50.03it/s, v_num=0, train_acc=0.968, val_loss=0.348, val_acc=0.971]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 101.32it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 108.13it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 83.97it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 91.16it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 99.14it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 105.19it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 107.03it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 110.88it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 110.40it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 112.85it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 113.53it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 113.84it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 115.37it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 114.89it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 115.89it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 116.44it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 116.49it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 114.89it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 114.37it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 115.50it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 116.35it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 116.78it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 117.04it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 117.58it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 118.10it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 119.13it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 119.67it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 119.77it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 120.51it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 121.48it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 122.08it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 122.78it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 122.94it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 122.22it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 122.64it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 123.28it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 123.75it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 123.99it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 124.12it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 125.60it/s]
# Epoch 16: 100%|██████████| 215/215 [00:04<00:00, 44.49it/s, v_num=0, train_acc=0.995, val_loss=0.642, val_acc=0.953]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 41.25it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 60.60it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 69.35it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 76.03it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 81.90it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 89.23it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 94.57it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 99.24it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 96.23it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 98.27it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 101.32it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 104.77it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 107.24it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 107.91it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 109.95it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 110.22it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 109.83it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 110.59it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 110.80it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 109.41it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 109.28it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 108.59it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 108.83it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 107.59it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 108.32it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 108.71it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 109.23it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 109.75it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 109.37it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 110.29it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 110.53it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 110.95it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 110.99it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 111.32it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 111.71it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 112.29it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 112.85it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 113.08it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 113.43it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 114.44it/s]
# Epoch 17: 100%|██████████| 215/215 [00:04<00:00, 45.74it/s, v_num=0, train_acc=0.995, val_loss=0.531, val_acc=0.961]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 54.84it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 53.08it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 55.77it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 64.20it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 67.32it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 70.87it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 75.44it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 75.79it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 74.79it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 74.92it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 75.84it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 78.83it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 78.59it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 78.96it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 80.55it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 81.34it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 80.40it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 80.05it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 79.21it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 80.48it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 79.49it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 78.80it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 78.58it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 79.61it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 79.77it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 80.18it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 80.47it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 81.21it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 82.26it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 81.94it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 80.69it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 81.82it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 82.92it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 82.55it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 81.52it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 82.58it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 83.36it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 83.70it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 83.01it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 84.05it/s]
# Epoch 17: 100%|██████████| 215/215 [00:05<00:00, 41.05it/s, v_num=0, train_acc=0.995, val_loss=0.354, val_acc=0.973]
# Monitored metric val_loss did not improve in the last 3 records. Best score: 0.348. Signaling Trainer to stop.
# Epoch 17: 100%|██████████| 215/215 [00:05<00:00, 41.00it/s, v_num=0, train_acc=0.995, val_loss=0.354, val_acc=0.973]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 79/79 [00:00<00:00, 131.62it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.9754999876022339
#         test_loss           0.3307338058948517
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_loss': 0.3307338058948517, 'test_acc': 0.9754999876022339}]

# %%
# %reload_ext tensorboard
# %tensorboard --logdir=../models/cnn-scratch/lightning_logs/
# Out:
# Reusing TensorBoard on port 6006 (pid 6812), started 0:00:13 ago. (Use '!kill 6812' to kill it.)
#       <iframe id="tensorboard-frame-c38e3b16156bcfed" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c38e3b16156bcfed");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
