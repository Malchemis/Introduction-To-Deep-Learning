# %% [markdown]
# # CNN from scratch

# %%
# show version and all available gpu devices
import torch
print(torch.__version__)
if torch.cuda.is_available():
    for idx in range(torch.cuda.device_count()):
        print(torch.cuda.get_device_name(idx))
else:
    print('No GPU available')
# Out:
# 2.5.1
# NVIDIA GeForce GTX 1050

# %%
from torch import nn


class MyConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding='same', dilation=1, groups=1, bias=True):
        super(MyConv2d, self).__init__()        
        self.stride = (stride, stride) if isinstance(stride, int) else tuple(stride)
        self.dilation = (dilation, dilation) if isinstance(dilation, int) else tuple(dilation)
        self.kernel_size = (kernel_size, kernel_size) if isinstance(kernel_size, int) else tuple(kernel_size)
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.groups = self.check_params(groups)
        self.bias = bias

        if isinstance(padding, str):
            if padding.lower() == 'same':
                self.padding = tuple((s * (k - 1) // 2 for s, k in zip(self.stride, self.kernel_size)))
            elif padding.lower() == 'valid':
                self.padding = (0, 0)
            else:
                raise ValueError('Padding must be "same", "valid", or an integer.')
        else:
            self.padding = (padding, padding) if isinstance(padding, int) else tuple(padding)

        self.weight = nn.Parameter(
            torch.randn(out_channels, in_channels // groups, kernel_size, kernel_size)
        )
        self.bias = nn.Parameter(torch.randn(out_channels)) if bias else None
        
    def forward(self, x):
        # return self.my_forward(x) # a lot slower since it's not optimized, doesn't exploit parallelism
        return self.fold_forward(x)  # Optimized version using matrix multiplication and unfolding with parallelism
        # return self.default_forward(x) # Default PyTorch implementation
    
    def my_forward(self, x):
        batch_size, in_channels, height, width = x.size()

        # Check dimensions
        assert in_channels == self.in_channels, \
            f'Expected input with {self.in_channels} channels, but got {in_channels} channels'

        # Calculate output dimensions
        out_height = (height + 2 * self.padding[0] - self.dilation[0] * (self.kernel_size[0] - 1) - 1) // self.stride[0] + 1
        out_width = (width + 2 * self.padding[1] - self.dilation[1] * (self.kernel_size[1] - 1) - 1) // self.stride[1] + 1

        # Apply padding if needed
        if self.padding != (0, 0):
            x = nn.functional.pad(x, (self.padding[1], self.padding[1], self.padding[0], self.padding[0]))

        # Initialize the output tensor
        out = torch.zeros((batch_size, self.out_channels, out_height, out_width), device=x.device)

        # Perform the convolution operation
        out_channels_per_group = self.out_channels // self.groups
        in_channels_per_group = self.in_channels // self.groups

        for g in range(self.groups):
            for i in range(out_height):
                for j in range(out_width):
                    h_start = i * self.stride[0]
                    h_end = h_start + self.kernel_size[0] * self.dilation[0]
                    w_start = j * self.stride[1]
                    w_end = w_start + self.kernel_size[1] * self.dilation[1]

                    x_slice = x[:, g * in_channels_per_group:(g + 1) * in_channels_per_group, h_start:h_end:self.dilation[0], w_start:w_end:self.dilation[1]]

                    out[:, g * out_channels_per_group:(g + 1) * out_channels_per_group, i, j] = \
                        torch.einsum('bijk,oijk->bo', x_slice, self.weight[g * out_channels_per_group:(g + 1) * out_channels_per_group]) + \
                        self.bias[g * out_channels_per_group:(g + 1) * out_channels_per_group]

        return out

    def fold_forward(self, x):
        """Reproduces F.conv2d with the specified parameters without the explicit call to the function."""
        n_batch, in_channels, in_height, in_width = x.size()
        out_height = (in_height + 2 * self.padding[0] - self.dilation[0] * (self.kernel_size[0] - 1) - 1) // self.stride[0] + 1
        out_width = (in_width + 2 * self.padding[1] - self.dilation[1] * (self.kernel_size[1] - 1) - 1) // self.stride[1] + 1
    
        # Pad the input tensor
        if self.padding != (0, 0):
            x = nn.functional.pad(x, (self.padding[1], self.padding[1], self.padding[0], self.padding[0]))
    
        # Unfold the input tensor to apply the convolution operation
        x = torch.nn.functional.unfold(x, self.kernel_size, dilation=self.dilation, stride=self.stride)
    
        # Reshape the weights
        weight = self.weight.view(self.weight.size(0), -1)
    
        # Perform matrix multiplication
        x = torch.matmul(x.permute(0, 2, 1), weight.t())
        
        # Reshape the output tensor
        x = x.view(n_batch, self.out_channels, out_height, out_width)
    
        return x + self.bias.view(1, -1, 1, 1) if self.bias is not None else x


    def default_forward(self, x):
        return F.conv2d(x, self.weight, self.bias, self.stride, self.padding, self.dilation, self.groups)

    def check_params(self, groups):
        """Checks the parameters of the Conv2d layer to ensure they are valid."""
        if groups <= 0:
            raise ValueError('groups must be a positive integer')
        if self.in_channels % groups != 0:
            raise ValueError('in_channels must be divisible by groups')
        if self.out_channels % groups != 0:
            raise ValueError('out_channels must be divisible by groups')
        return groups

# %%
import torch
from torch import nn
import torch.nn.functional as F

from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms

import pytorch_lightning as pl
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import EarlyStopping
import torchmetrics

class MNISTModel(pl.LightningModule):
    def __init__(self):
        super().__init__()
        self.mnist_val = None
        self.mnist_train = None
        self.mnist_test = None
        self.convBlock1 = nn.Sequential(
            MyConv2d(1, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.convBlock2 = nn.Sequential(
            MyConv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.fc_out = nn.Linear(64 * 7 * 7, 10)
        
        # Initialize metrics
        self.train_accuracy = torchmetrics.Accuracy(task='multiclass', num_classes=10)
        self.val_accuracy = torchmetrics.Accuracy(task='multiclass', num_classes=10)
        self.test_accuracy = torchmetrics.Accuracy(task='multiclass', num_classes=10)

    def forward(self, x):
        x = self.convBlock1(x)
        x = self.convBlock2(x)
        x = x.view(x.size(0), -1)  # Flatten the tensor
        return self.fc_out(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        logits = self.forward(x)
        loss = F.cross_entropy(logits, y)
        
        # Calculate and log accuracy
        preds = torch.argmax(logits, dim=1)
        acc = self.train_accuracy(preds, y)
        self.log('train_loss', loss)
        self.log('train_acc', acc, prog_bar=True)
        
        return loss
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        logits = self.forward(x)
        loss = F.cross_entropy(logits, y)
        
        # Calculate and log accuracy
        preds = torch.argmax(logits, dim=1)
        acc = self.val_accuracy(preds, y)
        self.log('val_loss', loss, prog_bar=True)
        self.log('val_acc', acc, prog_bar=True)
        
        return loss

    def test_step(self, batch, batch_idx):
        x, y = batch
        logits = self.forward(x)
        loss = F.cross_entropy(logits, y)
        
        # Calculate and log accuracy
        preds = torch.argmax(logits, dim=1)
        acc = self.test_accuracy(preds, y)
        self.log('test_loss', loss, prog_bar=True)
        self.log('test_acc', acc, prog_bar=True)
        
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=0.001)

    def prepare_data(self):
        # Download and prepare the MNIST dataset
        datasets.MNIST('../data/raw', train=True, download=True)
        datasets.MNIST('../data/raw', train=False, download=True)

    def setup(self, stage=None):
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.1307,), (0.3081,))
        ])
        if stage == 'fit' or stage is None:
            mnist_full = datasets.MNIST('../data/raw', train=True, transform=transform)
            self.mnist_train, self.mnist_val = random_split(mnist_full, [55000, 5000])
        if stage == 'test' or stage is None:
            self.mnist_test = datasets.MNIST('../data/raw', train=False, transform=transform)

    def train_dataloader(self):
        return DataLoader(self.mnist_train, batch_size=256, num_workers=8, shuffle=True, persistent_workers=True)

    def val_dataloader(self):
        return DataLoader(self.mnist_val, batch_size=128, num_workers=8, shuffle=False, persistent_workers=True)
    
    def test_dataloader(self):
        return DataLoader(self.mnist_test, batch_size=128, num_workers=8, shuffle=False, persistent_workers=True)

# %%
# EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Metric to monitor
    patience=3,  # Number of epochs with no improvement after which training will be stopped
    verbose=True,  # Print messages when early stopping is triggered
    mode='min'  # Minimize the monitored metric
)

# Trainer with EarlyStopping callback
trainer = Trainer(max_epochs=50, callbacks=[early_stopping], accelerator='gpu', devices=1, default_root_dir='../models/cnn-scratch')
model = MNISTModel()
trainer.fit(model)

# Get best weights from checkpoint
best_model_path = trainer.checkpoint_callback.best_model_path
model = MNISTModel.load_from_checkpoint(best_model_path)

# Test the model
trainer.test(model)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name           | Type               | Params | Mode
# --------------------------------------------------------------
# 0 | convBlock1     | Sequential         | 320    | train
# 1 | convBlock2     | Sequential         | 18.5 K | train
# 2 | fc_out         | Linear             | 31.4 K | train
# 3 | train_accuracy | MulticlassAccuracy | 0      | train
# 4 | val_accuracy   | MulticlassAccuracy | 0      | train
# 5 | test_accuracy  | MulticlassAccuracy | 0      | train
# --------------------------------------------------------------
# 50.2 K    Trainable params
# 0         Non-trainable params
# 50.2 K    Total params
# 0.201     Total estimated model params size (MB)
# 12        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 215/215 [00:08<00:00, 24.15it/s, v_num=1, train_acc=0.875]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:01, 27.70it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 31.37it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 39.20it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 43.74it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 45.61it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 49.07it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 50.56it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 52.08it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 52.39it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 52.41it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 52.66it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 53.50it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 53.78it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 54.50it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 54.90it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 55.52it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 55.68it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 56.03it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 56.28it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 56.60it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 56.72it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 56.77it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 56.73it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 56.76it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 57.15it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 57.41it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 57.85it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 58.36it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 58.76it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 59.07it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 59.29it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 59.36it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 59.16it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 59.39it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 59.64it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 59.79it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 60.08it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 60.23it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 60.38it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 61.27it/s]
# Epoch 0: 100%|██████████| 215/215 [00:09<00:00, 22.26it/s, v_num=1, train_acc=0.875, val_loss=1.530, val_acc=0.912]
# Metric val_loss improved. New best score: 1.530
# Epoch 1: 100%|██████████| 215/215 [00:08<00:00, 24.14it/s, v_num=1, train_acc=0.921, val_loss=1.530, val_acc=0.912]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 43.99it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 51.36it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 53.36it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 55.17it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 56.47it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 57.45it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 58.30it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 58.86it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 53.87it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 55.36it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 56.33it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 57.20it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 58.03it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 58.44it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 58.69it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 59.35it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 59.36it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 58.59it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 58.35it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 58.52it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 58.73it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 58.60it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 58.50it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 58.55it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 58.04it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 58.10it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 58.17it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 58.33it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 58.65it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 58.71it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 58.78it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 58.99it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 59.18it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 59.43it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 59.18it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 59.35it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 59.66it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 59.80it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 59.91it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 60.79it/s]
# Epoch 1: 100%|██████████| 215/215 [00:09<00:00, 22.22it/s, v_num=1, train_acc=0.921, val_loss=0.834, val_acc=0.935]
# Metric val_loss improved by 0.696 >= min_delta = 0.0. New best score: 0.834
# Epoch 2: 100%|██████████| 215/215 [00:08<00:00, 24.13it/s, v_num=1, train_acc=0.940, val_loss=0.834, val_acc=0.935]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:01, 36.53it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 48.49it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 53.97it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 55.45it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 57.48it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 58.49it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 56.93it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 57.20it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 53.23it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 53.80it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 54.70it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 55.20it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 55.91it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 56.78it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 56.99it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 57.63it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 57.68it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 58.11it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 58.51it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 58.76it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 58.31it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 57.91it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 57.86it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 57.58it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 57.93it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 58.07it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 58.42it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 58.60it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 58.74it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 58.68it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 58.44it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 58.71it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 58.85it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 59.03it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 59.36it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 59.35it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 59.63it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 59.61it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 59.76it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 60.62it/s]
# Epoch 3: 100%|██████████| 215/215 [00:09<00:00, 23.18it/s, v_num=1, train_acc=0.944, val_loss=0.926, val_acc=0.927]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 56.79it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 61.24it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 63.72it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 64.36it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 64.37it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 64.65it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 63.30it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 63.47it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 61.07it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 61.74it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 61.95it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 61.86it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 62.06it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 62.13it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 62.30it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 62.53it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 61.75it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 62.03it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 62.00it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 61.61it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 61.34it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 60.80it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 60.88it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 60.78it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 61.04it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 61.16it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 61.32it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 61.44it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 61.43it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 61.29it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 61.24it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 61.54it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 61.81it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 61.84it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 61.97it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 61.88it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 61.56it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 61.50it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 61.65it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 62.34it/s]
# Epoch 4: 100%|██████████| 215/215 [00:09<00:00, 22.91it/s, v_num=1, train_acc=0.954, val_loss=0.858, val_acc=0.931]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 60.36it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 65.53it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 66.99it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 69.03it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 69.68it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 64.48it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 64.68it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 64.70it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 62.17it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 63.05it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 64.39it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 64.45it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 65.15it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 65.14it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 65.69it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 66.27it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 64.76it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 64.52it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 64.38it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 64.69it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 64.97it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 65.16it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 64.89it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 65.09it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 64.61it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 64.91it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 65.15it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 65.37it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 65.47it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 65.44it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 65.62it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 65.83it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 66.15it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 66.22it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 66.30it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 66.06it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 66.18it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 66.10it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 65.73it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 66.14it/s]
# Epoch 4: 100%|██████████| 215/215 [00:10<00:00, 21.29it/s, v_num=1, train_acc=0.954, val_loss=0.552, val_acc=0.947]
# Metric val_loss improved by 0.282 >= min_delta = 0.0. New best score: 0.552
# Epoch 5: 100%|██████████| 215/215 [00:09<00:00, 23.80it/s, v_num=1, train_acc=0.963, val_loss=0.552, val_acc=0.947]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 70.02it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 73.40it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 75.91it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 74.62it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 75.56it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 75.82it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 74.67it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 74.59it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 69.14it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 69.25it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 70.29it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 71.13it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 70.79it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 71.02it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 71.02it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 71.29it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 70.99it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 70.83it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 70.53it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 70.37it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 70.24it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 70.19it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 70.25it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 70.20it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 70.14it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 69.94it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 69.65it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 69.84it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 70.13it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 70.12it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 70.05it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 70.39it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 70.58it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 70.72it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 70.95it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 71.06it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 71.00it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 70.97it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 70.61it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 71.38it/s]
# Epoch 6: 100%|██████████| 215/215 [00:09<00:00, 23.50it/s, v_num=1, train_acc=0.940, val_loss=0.558, val_acc=0.955]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:01, 33.07it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 32.97it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 37.87it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 41.07it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 42.41it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 45.28it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 47.25it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 48.77it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 47.45it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 48.52it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 49.49it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 50.27it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 50.63it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 51.39it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 51.80it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 52.45it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 52.40it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 52.95it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 53.12it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 53.24it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 53.40it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 53.57it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 53.61it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 53.50it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 53.60it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 53.89it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 54.01it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 54.36it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 54.46it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 54.78it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 55.19it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 55.35it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 55.61it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 55.77it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 55.87it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 56.15it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 56.35it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 56.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 56.67it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 57.45it/s]
# Epoch 7: 100%|██████████| 215/215 [00:09<00:00, 23.20it/s, v_num=1, train_acc=0.977, val_loss=0.744, val_acc=0.932]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 58.01it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 60.98it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 59.91it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 61.04it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 61.86it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 62.10it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 62.42it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 63.26it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 60.66it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 61.38it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 61.51it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 61.62it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 62.40it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 61.89it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 61.56it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 61.90it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 62.20it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 61.99it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 62.18it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 61.88it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 61.79it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 61.73it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 61.22it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 61.07it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 61.08it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 61.09it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 61.39it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 61.12it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 61.30it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 61.54it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 61.54it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 61.74it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 61.88it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 62.13it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 62.21it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 62.16it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 62.38it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 62.46it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 62.25it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 63.09it/s]
# Epoch 7: 100%|██████████| 215/215 [00:10<00:00, 21.43it/s, v_num=1, train_acc=0.977, val_loss=0.488, val_acc=0.956]
# Metric val_loss improved by 0.064 >= min_delta = 0.0. New best score: 0.488
# Epoch 8: 100%|██████████| 215/215 [00:09<00:00, 23.61it/s, v_num=1, train_acc=0.981, val_loss=0.488, val_acc=0.956]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:01, 27.25it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 26.76it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:01, 32.94it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:01, 34.38it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 38.39it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 41.23it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 43.49it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 45.49it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 46.52it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 47.71it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 48.64it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 49.21it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 49.37it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 49.86it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 50.59it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 51.39it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 51.94it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 51.90it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 51.44it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 51.58it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 51.71it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 52.06it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 52.28it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 52.72it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 53.21it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 53.56it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 54.10it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 54.42it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 54.78it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 55.01it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 55.20it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 55.45it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 55.84it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 56.07it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 56.30it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 56.56it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 56.83it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 57.10it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 57.27it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 57.96it/s]
# Epoch 9: 100%|██████████| 215/215 [00:09<00:00, 23.76it/s, v_num=1, train_acc=0.958, val_loss=0.489, val_acc=0.956]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:01, 24.12it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 24.87it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:01, 29.62it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:01, 34.04it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 36.39it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 38.12it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 39.35it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 41.05it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 42.70it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 44.13it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 44.52it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 45.55it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 46.54it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 47.22it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 47.33it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 48.15it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 48.43it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 48.82it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 49.08it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 49.18it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 49.45it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 49.76it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 49.65it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 49.58it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 49.86it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 49.93it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 50.21it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 50.64it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 50.80it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 51.08it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 51.23it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 51.42it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 51.57it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 51.69it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 51.90it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 52.06it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 52.25it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 52.23it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 52.31it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 53.10it/s]
# Epoch 9: 100%|██████████| 215/215 [00:09<00:00, 21.80it/s, v_num=1, train_acc=0.958, val_loss=0.452, val_acc=0.960]
# Metric val_loss improved by 0.035 >= min_delta = 0.0. New best score: 0.452
# Epoch 10: 100%|██████████| 215/215 [00:08<00:00, 24.14it/s, v_num=1, train_acc=0.954, val_loss=0.452, val_acc=0.960]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:01, 30.54it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 39.08it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 41.42it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 46.04it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 47.77it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 49.77it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 50.91it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 52.54it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 52.63it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 53.37it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 53.49it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 54.14it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 54.57it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 54.80it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 54.59it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 55.21it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 55.26it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 55.61it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 56.20it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 56.42it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 56.79it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 56.91it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 56.89it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 56.92it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 57.28it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 57.57it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 57.74it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 57.86it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 58.12it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 58.05it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 58.17it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 58.18it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 58.08it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 58.04it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 58.14it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 58.36it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 58.55it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 58.59it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 58.71it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 59.46it/s]
# Epoch 10: 100%|██████████| 215/215 [00:09<00:00, 22.22it/s, v_num=1, train_acc=0.954, val_loss=0.424, val_acc=0.963]
# Metric val_loss improved by 0.028 >= min_delta = 0.0. New best score: 0.424
# Epoch 11: 100%|██████████| 215/215 [00:09<00:00, 23.84it/s, v_num=1, train_acc=0.977, val_loss=0.424, val_acc=0.963]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 39.98it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 51.77it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 55.79it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 52.46it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 54.98it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 55.87it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 57.47it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 57.78it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 55.61it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 56.26it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 57.15it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 56.98it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 57.70it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 57.73it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 57.95it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 58.30it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 58.08it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 57.94it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 58.15it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 58.17it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 58.02it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 57.95it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 57.78it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 58.01it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 58.19it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 58.31it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 58.57it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 58.75it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 58.96it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 59.14it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 59.11it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 59.39it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 59.57it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 59.75it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 59.74it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 59.74it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 60.12it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 60.01it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 60.00it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 60.85it/s]
# Epoch 12: 100%|██████████| 215/215 [00:08<00:00, 24.05it/s, v_num=1, train_acc=0.986, val_loss=0.505, val_acc=0.956]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:01, 31.79it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 42.67it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 47.01it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 49.69it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 52.45it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 54.42it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 56.25it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 57.23it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 56.16it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 56.92it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 56.72it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 56.59it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 56.36it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 56.90it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 57.12it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 57.42it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 57.13it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 57.54it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 57.58it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 57.72it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 58.01it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 57.71it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 58.26it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 58.44it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 58.78it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 59.40it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 59.83it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 59.96it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 60.35it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 60.65it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 60.89it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 61.23it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 61.57it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 61.67it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 61.83it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 62.09it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 62.21it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 62.36it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 62.37it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 63.29it/s]
# Epoch 13: 100%|██████████| 215/215 [00:08<00:00, 24.09it/s, v_num=1, train_acc=0.968, val_loss=0.446, val_acc=0.960]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:01, 38.49it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 46.39it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 50.67it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 50.89it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 53.19it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 54.42it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 55.22it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 56.09it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 54.78it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 54.78it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 56.03it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 56.36it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 57.37it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 57.91it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 58.32it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 58.76it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 58.70it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 58.71it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 58.84it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 58.71it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 58.98it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 59.06it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 59.08it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 58.91it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 59.13it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 59.61it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 60.08it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 60.32it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 60.49it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 60.60it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 60.53it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 60.93it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 61.15it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 61.26it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 61.40it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 61.40it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 61.38it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 61.34it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 61.32it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 62.01it/s]
# Epoch 13: 100%|██████████| 215/215 [00:09<00:00, 22.20it/s, v_num=1, train_acc=0.968, val_loss=0.353, val_acc=0.967]
# Metric val_loss improved by 0.071 >= min_delta = 0.0. New best score: 0.353
# Epoch 14: 100%|██████████| 215/215 [00:09<00:00, 23.65it/s, v_num=1, train_acc=0.977, val_loss=0.353, val_acc=0.967]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:01, 32.15it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 41.06it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 47.05it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 50.04it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 51.74it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 54.11it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 54.49it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 54.71it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 52.89it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 53.61it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 54.17it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 54.84it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 55.43it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 55.84it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 56.39it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 56.17it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 56.23it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 56.55it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 56.72it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 56.85it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 56.70it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 56.56it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 56.58it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 56.62it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 57.01it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 57.18it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 57.26it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 57.36it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 57.47it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 57.79it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 57.85it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 58.02it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 58.19it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 58.44it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 58.47it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 58.57it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 58.73it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 58.88it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 58.77it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 59.35it/s]
# Epoch 15: 100%|██████████| 215/215 [00:09<00:00, 23.24it/s, v_num=1, train_acc=0.981, val_loss=0.397, val_acc=0.965]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 46.93it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 56.89it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 60.14it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 61.98it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 61.84it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 62.75it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 63.96it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 64.20it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 59.50it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 60.24it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 60.57it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 61.77it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 62.53it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 62.61it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 62.95it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 62.88it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 62.16it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 62.48it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 62.16it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 61.98it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 61.83it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 61.45it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 61.41it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 61.31it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 61.64it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 61.88it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 61.98it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 62.27it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 62.64it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 62.85it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 62.98it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 62.85it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 62.77it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 62.68it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 62.81it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 63.04it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 63.19it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 63.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 63.13it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 63.99it/s]
# Epoch 16: 100%|██████████| 215/215 [00:08<00:00, 24.11it/s, v_num=1, train_acc=0.981, val_loss=0.426, val_acc=0.966]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:01, 29.01it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 35.69it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 42.98it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 47.53it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 50.55it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 51.04it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 52.99it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 54.86it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 53.71it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 53.57it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 54.40it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 55.10it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 56.20it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 56.62it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 57.09it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 57.71it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 57.96it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 58.20it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 58.16it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 58.19it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 58.04it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 58.23it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 58.42it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 58.41it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 58.63it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 58.61it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 58.70it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 58.83it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 59.09it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 59.28it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 59.30it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 59.66it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 59.94it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 59.77it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 59.73it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 59.60it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 59.78it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 59.84it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 59.64it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 60.38it/s]
# Epoch 16: 100%|██████████| 215/215 [00:09<00:00, 22.25it/s, v_num=1, train_acc=0.981, val_loss=0.380, val_acc=0.966]
# Monitored metric val_loss did not improve in the last 3 records. Best score: 0.353. Signaling Trainer to stop.
# Epoch 16: 100%|██████████| 215/215 [00:09<00:00, 22.22it/s, v_num=1, train_acc=0.981, val_loss=0.380, val_acc=0.966]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 79/79 [00:01<00:00, 66.24it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.9653000235557556
#         test_loss           0.41163358092308044
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_loss': 0.41163358092308044, 'test_acc': 0.9653000235557556}]

# %%
# %reload_ext tensorboard
# %tensorboard --logdir=../models/cnn-scratch/lightning_logs/
# Out:
# Reusing TensorBoard on port 6007 (pid 11622), started 0:00:28 ago. (Use '!kill 11622' to kill it.)
#       <iframe id="tensorboard-frame-cdfa9bfca38f1bfa" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-cdfa9bfca38f1bfa");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
